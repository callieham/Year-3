# %%
import math

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
def unif_sum_samples(n):
    samples = []
    for i in range(n):
        unif_samples = np.random.uniform(0, 1, 12)
        samples.append(np.sum(unif_samples) - 6)
    return samples

# %%
my_unif_sum_samples = unif_sum_samples(100000)

# %%
unif_sum = np.random.normal(0, 1, 100000)

# %%
plt.hist(unif_sum, bins = 50, alpha = 0.7)
plt.hist(my_unif_sum_samples, bins = 50, alpha = 0.7)
# Out:
# (array([1.000e+00, 0.000e+00, 3.000e+00, 6.000e+00, 1.100e+01, 2.500e+01,
#         2.900e+01, 6.800e+01, 1.160e+02, 1.910e+02, 2.950e+02, 4.970e+02,
#         7.130e+02, 1.018e+03, 1.384e+03, 1.884e+03, 2.376e+03, 3.033e+03,
#         3.616e+03, 4.166e+03, 5.024e+03, 5.470e+03, 5.962e+03, 6.469e+03,
#         6.677e+03, 6.591e+03, 6.492e+03, 6.225e+03, 5.591e+03, 5.155e+03,
#         4.508e+03, 3.848e+03, 3.134e+03, 2.584e+03, 1.923e+03, 1.505e+03,
#         1.112e+03, 8.210e+02, 5.300e+02, 3.700e+02, 2.400e+02, 1.550e+02,
#         7.500e+01, 5.400e+01, 3.100e+01, 1.500e+01, 5.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([-4.23862741, -4.07008643, -3.90154545, -3.73300447, -3.56446349,
#         -3.39592251, -3.22738154, -3.05884056, -2.89029958, -2.7217586 ,
#         -2.55321762, -2.38467664, -2.21613566, -2.04759468, -1.8790537 ,
#         -1.71051272, -1.54197174, -1.37343076, -1.20488978, -1.0363488 ,
#         -0.86780782, -0.69926685, -0.53072587, -0.36218489, -0.19364391,
#         -0.02510293,  0.14343805,  0.31197903,  0.48052001,  0.64906099,
#          0.81760197,  0.98614295,  1.15468393,  1.32322491,  1.49176589,
#          1.66030687,  1.82884784,  1.99738882,  2.1659298 ,  2.33447078,
#          2.50301176,  2.67155274,  2.84009372,  3.0086347 ,  3.17717568,
#          3.34571666,  3.51425764,  3.68279862,  3.8513396 ,  4.01988058,
#          4.18842156]),
#  <BarContainer object of 50 artists>)

# %%
from scipy.stats import norm

# %%
fig, ax = plt.subplots(1, 1)
x = np.linspace(norm.ppf(0.01), norm.ppf(0.99), 100)
ax.plot(x, norm.pdf(x), lw=2)
ax.hist(my_unif_sum_samples, bins=50, alpha=0.5, density = True)
plt.show()

# %%
def exp_samples(n, l):
    samples = []
    for i in range(n):
        unif = np.random.uniform(0, 1)
        samples.append(-math.log(unif)/l)
    return samples

# %%
from scipy.stats import expon
fig, ax = plt.subplots(1, 1)
x = np.linspace(expon.ppf(0.01), expon.ppf(0.99), 100)
ax.plot(x, expon.pdf(x), lw=2)
ax.hist(exp_samples(10000, 1), density = True, bins = 50)
plt.show()

# %%
def weibull(n, beta, alpha = 1):
    unifs = np.random.uniform(0, 1, n)
    weibs = alpha*(-np.log(unifs))**(1/beta)
    return list(weibs)

# %%
beta = 10

# %%
my_weibs = weibull(10000, beta)

# %%
from scipy.stats import weibull_min
fig, ax = plt.subplots(1, 1)
x = np.linspace(weibull_min.ppf(0.01, beta), weibull_min.ppf(0.99, beta), 100)
ax.plot(x, weibull_min.pdf(x, beta), lw=2)
ax.hist(my_weibs, density = True, bins = 50)
plt.show()

# %%
def circle_samples(n, power=1):
    r_unifs = np.random.uniform(0, 1, n)
    theta_unifs = np.random.uniform(-np.pi, np.pi, n)
    samples_x = (r_unifs**power)*np.cos(theta_unifs)
    samples_y = (r_unifs**power)*np.sin(theta_unifs)
    return samples_x, samples_y

# %%
x_1, x_2 = circle_samples(10000, 0.5)

# %%
plt.scatter(x_1, x_2, s = 0.1)
plt.gca().set_aspect('equal')
